# %% [markdown]
# # Die BSTree-Datenstruktur
#
# ## Agenda
#
# - API
# - Implementierung
#     - Suche
#     - Hinzufügen
#     - Entfernen
#     - Iteration / Traversierung
# - Laufzeitkomplexität

# %% [markdown]
# ## API

# %%
class BSTree:
    class Node:
        def __init__(self, val, left=None, right=None):
            self.val = val
            self.left = left
            self.right = right
            
    def __init__(self):
        self.size = 0
        self.root = None
    
    def __contains__(self, val):
        """Returns `True` if val is in this tree and `False` otherwise."""
        pass
    
    def add(self, val):
        """Adds `val` to this tree while maintaining BSTree properties."""
        assert val not in self
        pass    

    def __delitem__(self, val):
        """Removes `val` from this tree while maintaining BSTree properties."""
        assert val in self
        pass
    
    def __iter__(self):
        """Returns an iterator over all the values in the tree, in ascending order."""
        pass

    def __len__(self):
        return self.size
    
    def height(self):
        """Returns the height of the root of the tree."""
        def height_rec(t):
            if not t:
                return 0
            else:
                return 1 + max(height_rec(t.left), height_rec(t.right))
        return height_rec(self.root)

    def pprint(self, width=64):
        """Attempts to pretty-print this tree's contents."""
        height = self.height()
        nodes  = [(self.root, 0)]
        prev_level = 0
        repr_str = ''
        while nodes:
            n,level = nodes.pop(0)
            if prev_level != level:
                prev_level = level
                repr_str += '\n'
            if not n:
                if level < height-1:
                    nodes.extend([(None, level+1), (None, level+1)])
                repr_str += '{val:^{width}}'.format(val='-', width=width//2**level)
            elif n:
                if n.left or level < height-1:
                    nodes.append((n.left, level+1))
                if n.right or level < height-1:
                    nodes.append((n.right, level+1))
                repr_str += '{val:^{width}}'.format(val=n.val, width=width//2**level)
        print(repr_str)

# %%
t = BSTree()
t.root = BSTree.Node(5,
                    left=BSTree.Node(2),
                    right=BSTree.Node(10))
t.size = 3

# %%
t.height()

# %%
t.pprint()

# %% [markdown]
# ## Implementierung

# %% [markdown]
# ### Suche

# %%
class BSTree(BSTree):
    def __contains__(self, val):
        def contains_rec(node):
            pass

# %%
t = BSTree()
t.root = BSTree.Node(5,
                    left=BSTree.Node(2),
                    right=BSTree.Node(10))
t.size = 3

# %%
3 in t

# %% [markdown]
# ### Addition

# %%
class BSTree(BSTree):
    def add(self, val):
        pass

# %%
import random
t = BSTree()
vals = list(range(10))
random.shuffle(vals)
for x in vals:
    t.add(x)
t.pprint()

# %% [markdown]
# ### Löschen
# Es gibt drei verschiedene Fälle. Der zu löschende Knoten:
# - ist ein Blattknoten (hat keine Kinder) -> einfach, einfach löschen
# - hat nur ein Kind (links oder rechts) -> mehr oder weniger einfach, das Kind eine Ebene höher setzen
# - hat zwei Kinder -> hmm, das ist schwierig
#
# Lassen Sie uns zuerst die einfachen Fälle behandeln:

# %%
class BSTree(BSTree):
    def __delitem__(self, val):
         pass

# %%
t = BSTree()
for x in [10, 5, 15, 2, 17]:
    t.add(x)
t.pprint()

# %%
del t[2]
t.pprint()

# %%
t = BSTree()
for x in [10, 5, 15, 2, 17]:
    t.add(x)
t.pprint()

# %%
del t[5]
t.pprint()

# %%
t = BSTree()
for x in [10, 5, 15, 2, 17]:
    t.add(x)
t.pprint()

# %%
del t[15]
t.pprint()

# %%
t = BSTree()
for x in [10, 5, 15, 2, 17]:
    t.add(x)
t.pprint()

# %%
del t[10]
t.pprint()

# %% [markdown]
# Nun ja, ... es sieht so aus, als müssten wir jetzt den komplexen Fall behandeln.
#
# Vorschläge?
#
# Es gibt verschiedene Strategien:

# %%
class BSTree(BSTree):
    def __delitem__(self, val):
        assert val in self
        def delitem_rec(node):
            if val < node.val:
                node.left = delitem_rec(node.left)
                return node
            elif val > node.val:
                node.right = delitem_rec(node.right)
                return node
            else:
                if not node.left and not node.right:
                    return None
                elif node.left and not node.right:
                    return node.left
                elif node.right and not node.left:
                    return node.right
                else:
                    # handle the complex case
                    max = node.left
                    if max.right is None:
                        node.left = max.left
                    else:
                        prevMax = max
                        max = max.right
                        while max.right:
                            prevMax = max
                            max = max.right
                        prevMax.right = max.left

                    node.val = max.val
                    return node

        self.root = delitem_rec(self.root)
        self.size -= 1

# %%
t = BSTree()
for x in [10, 5, 2, 3, 7, 9,  8, 1, 15, 12, 6, 18]:
    t.add(x)
t.pprint()

# %%
del t[15]
t.pprint()

# %%
t = BSTree()
for x in [10, 5, 2, 7, 9, 8, 1, 15, 12, 18]:
    t.add(x)
t.pprint()

# %%
del t[5]
t.pprint()

# %%
t = BSTree()
for x in [10, 5, 2, 7, 9, 8, 1, 15, 12, 18]:
    t.add(x)
t.pprint()

# %%
del t[10]
t.pprint()

# %% [markdown]
# ### Iteration / Durchlauf

# %%
class BSTree(BSTree):
    def __iter__(self):
       pass

# %%
import random
t = BSTree()
vals = list(range(20))
random.shuffle(vals)
for x in vals:
    t.add(x)
t.pprint()
for x in t:
    print(x)

# %% [markdown]
# ### Iteration nach Ebenen

# %%
class BSTree(BSTree):
    def __iter__(self):
        pass

# %%
import random
t = BSTree()
vals = list(range(10))
random.shuffle(vals)
for x in vals:
    t.add(x)
t.pprint()

# %%
for x in t:
    print(x)

# %% [markdown]
# ## Laufzeitkomplexität

# %% [markdown]
# Die Laufzeitkomplexität der Such-, Einfüge- und Löschmethoden des binären Suchbaums hängt letztendlich von der Tiefe ihrer rekursiven Implementierung ab. Die Rekursionstiefe wiederum hängt von der Höhe des binären Suchbaums ab.
#
# Gegeben sind $N$ Knoten, die Höhe eines binären Suchbaums ist im schlimmsten Fall = ?
#
# Dies ergibt folgende Laufzeitkomplexitäten im schlimmsten Fall:
#
# - Suche = O(?)
# - Einfügen = O(?)
# - Löschen = O(?)
#
# Wie können wir diese Laufzeitkomplexität verbessern? Welches Ziel für die Laufzeitkomplexität sollten wir anstreben?
